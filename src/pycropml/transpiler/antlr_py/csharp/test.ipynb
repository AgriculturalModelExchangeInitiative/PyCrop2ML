# %%
components = "/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell"
from pycropml.transpiler.antlr_py import repowalk
files = repowalk.walk(components, 'cs')

# %%
files
# Out:
# {'SoiltempAuxiliary.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempAuxiliary.cs',
#  'SoiltempComponent.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempComponent.cs',
#  'SoilTemperature.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoilTemperature.cs',
#  'SoiltempExogenous.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempExogenous.cs',
#  'SoiltempRate.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempRate.cs',
#  'SoiltempState.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempState.cs',
#  'SoiltempWrapper.cs': '/mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempWrapper.cs'}

# %%
from pycropml.transpiler.antlr_py.to_CASG import to_dictASG, to_CASG
from pycropml.transpiler.antlr_py.csharp.csharpExtraction import CsharpExtraction

# %%
stra = {}
straNames = []
res = {}
for  k, v in files.items():
    print(v)
    with open(v, 'r') as f:
        code = f.read()
    dictasgt = to_dictASG(code,"cs")
    strAsg = to_CASG(dictasgt)
    res[k] = strAsg 
    m = CsharpExtraction()
    m.getTypeNode(strAsg, "classDef")
    g= m.getTree
    if k==2: print(g)
# Out:
# /mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempAuxiliary.cs
# /mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoiltempComponent.cs
# {'type': 'member_access', 'name': '_SoilTemperature', 'member': 'CalculateModel', 'pseudo_type': 'SoilTemperature'} SoilTemperature (346, 8) uuuuuuuuuuuu
# {'type': 'member_access', 'name': '_SoilTemperature', 'member': 'Init', 'pseudo_type': 'SoilTemperature'} SoilTemperature (420, 8) uuuuuuuuuuuu
# /mnt/d/Docs/AMEI_Workshop/AMEI_10_14_2022/Models/ApsimCampbell/src/cs/ApsimCampbell/SoilTemperature.cs
# {'type': 'member_access', 'name': 'Array', 'member': 'ConstrainedCopy', 'pseudo_type': None} None (1317, 17) uuuuuuuuuuuu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       6 with open(v, 'r') as f:
#       7     code = f.read()
# ----> 8 dictasgt = to_dictASG(code,"cs")
#       9 strAsg = to_CASG(dictasgt)
#      10 res[k] = strAsg
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/to_CASG.py:34, in to_dictASG(code, language, comments, env)
#      32 tree = parse.parsef(code,language, start="compilation_unit", strict=False)
#      33 ast_proc = simplifyAntlrTree.process_tree(tree,transformer_cls =GENERATORS[language].Transformer )
# ---> 34 trans = GENERATORS[language].AstTransformer(ast_proc,code, comments, env).transformer()
#      35 return trans
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:546, in AstTransformer.transformer(self)
#     544 self.namespace = []
#     545 self.top_level(self.tree)
# --> 546 body = self.visit(self.tree)
#     547 return {'body': body if isinstance(body, list) else [body]}
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:606, in AstTransformer.visit_compilation_unit(self, node, using_directives, namespace_member_declarations, location)
#     604         res2.append(us)
#     605     u = res2
# --> 606 z = self.visit(namespace_member_declarations)
#     607 return {"type": "module",
#     608         "using": u,
#     609         "body": z,
#     610         "pseudo_type": "Void"}
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:625, in AstTransformer.visit_namespace_member_declarations(self, node, namespace_member_declaration, location)
#     623 def visit_namespace_member_declarations(self,node, namespace_member_declaration, location):
# --> 625     return self.visit(node.children)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:686, in AstTransformer.visit_namespace_member_declaration(self, node, namespace_declaration, type_declaration, location)
#     684 def visit_namespace_member_declaration(self,node, namespace_declaration, type_declaration, location):
#     685     if type_declaration:
# --> 686         return   self.visit(type_declaration)
#     687     if namespace_declaration:
#     688         return self.visit(namespace_declaration)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:746, in AstTransformer.visit_type_declaration(self, node, class_definition, struct_definition, interface_definition, enum_definition, delegate_definition, attributes, all_member_modifiers, location)
#     744 name =  self.visit(class_definition.identifier)
#     745 self.clas.append(name)
# --> 746 block = self.visit(class_definition.class_body)
#     747 res = {"type":"classDef",
#     748         "name": name,
#     749         "base": self.visit(class_definition.class_base) if class_definition.class_base else None ,  #TODO
#     750         "block": block }
#     751 self.clas.pop()
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:769, in AstTransformer.visit_class_body(self, node, class_member_declarations, location)
#     767 def visit_class_body(self, node, class_member_declarations, location):
# --> 769     return self.visit(class_member_declarations)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:773, in AstTransformer.visit_class_member_declarations(self, node, class_member_declaration, location)
#     771 def visit_class_member_declarations(self, node, class_member_declaration, location):
# --> 773     return self.visit(node.children)
#     775     """
#     776     z = self.getpath(node, "typed_member_declaration")
#     777
#    (...)    792
#     793     return self.visit(class_member_declarations.children)"""
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:811, in AstTransformer.visit_class_member_declaration(self, node, common_member_declaration, destructor_definition, attributes, all_member_modifiers, location)
#     809     y = self.visit(attributes)
#     810 if common_member_declaration:
# --> 811     z = self.visit(common_member_declaration)
#     812     if z:
#     813         if x : z["modifiers"] = x
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:858, in AstTransformer.visit_common_member_declaration(self, node, constant_declaration, typed_member_declaration, event_declaration, conversion_operator_declarator, body, right_arrow, throwable_expression, constructor_declaration, VOID, method_declaration, class_definition, struct_definition, interface_definition, enum_definition, delegate_definition, location)
#     856 param = self.visit(method_declaration.formal_parameter_list)
#     857 ps = [p["pseudo_type"] for p in param] if param else [None]
# --> 858 block = self.visit(method_declaration.method_body)
#     859 modifiers = []
#     861 if param:
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1924, in AstTransformer.visit_ifstatement(self, node, expression, if_body, location, ELSE, IF)
#    1922 if len(if_body)==1:
#    1923     test = self.visit(expression)
# -> 1924     block = self.visit(if_body)
#    1925 else:
#    1926     test = self.visit(expression)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1927, in AstTransformer.visit_ifstatement(self, node, expression, if_body, location, ELSE, IF)
#    1925 else:
#    1926     test = self.visit(expression)
# -> 1927     block = self.visit(if_body[0])
#    1928     while(node.ELSE and "IF" in dir(node.if_body[1])):
#    1929         z = node.if_body[1]
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1468, in AstTransformer.visit_expressionstatement(self, node, expression, location)
#    1467 def visit_expressionstatement(self, node, expression, location):
# -> 1468     return self.visit(expression)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1396, in AstTransformer.visit_expression(self, node, assignment, non_assignment_expression, location)
#    1394 def visit_expression(self, node, assignment, non_assignment_expression, location):
#    1395     if non_assignment_expression:
# -> 1396         x = self.visit(non_assignment_expression)
#    1397         return  x[0] if isinstance(x, list) else x
#    1398     if assignment:
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1449, in AstTransformer.visit_non_assignment_expression(self, node, lambda_expression, query_expression, conditional_expression, location)
#    1447 if  lambda_expression: raise PseudoCythonTypeCheckError("Not implemented lambda expression , %s"%location)
#    1448 if  query_expression: raise PseudoCythonTypeCheckError("Not implemented query_expression , %s"%location)
# -> 1449 return self.visit(conditional_expression)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1453, in AstTransformer.visit_conditional_expression(self, node, null_coalescing_expression, throwable_expression, location)
#    1451 def visit_conditional_expression(self, node,null_coalescing_expression,throwable_expression, location):
#    1452     if null_coalescing_expression:
# -> 1453         res = self.visit(null_coalescing_expression)
#    1454     if throwable_expression:
#    1455         bodyif = self.visit(throwable_expression[0])
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1486, in AstTransformer.visit_conditional_or_expression(self, node, conditional_and_expression, OP_OR, location)
#    1480 def visit_conditional_or_expression(self,
#    1481                                     node,
#    1482                                     conditional_and_expression,
#    1483                                     OP_OR,
#    1484                                     location):
#    1485     if len(node.children)==1:
# -> 1486         return self.visit(conditional_and_expression)
#    1487     args = map(lambda n:self.visit(n), node.children)
#    1488     return reduceT(lambda x,y, op: {"type":"comparison", "op":op, "left":x if not isinstance(x, list) else x[0], "right":y if not isinstance(y, list) else y[0], "pseudo_type":"bool"}, list(args))
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1476, in AstTransformer.visit_conditional_and_expression(self, node, inclusive_or_expression, OP_AND, location)
#    1470 def visit_conditional_and_expression(self,
#    1471                                     node,
#    1472                                     inclusive_or_expression,
#    1473                                     OP_AND,
#    1474                                     location):
#    1475     if len(node.children)==1:
# -> 1476         return self.visit(inclusive_or_expression)
#    1477     args = map(lambda n:self.visit(n), node.children)
#    1478     return reduceT(lambda x,y, op: {"type":"comparison", "op":op, "left":x if not isinstance(x, list) else x[0], "right":y if not isinstance(y, list) else y[0], "pseudo_type":"bool"}, list(args))
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1504, in AstTransformer.visit_inclusive_or_expression(self, node, exclusive_or_expression, BITWISE_OR, location)
#    1499 def visit_inclusive_or_expression(self, node,
#    1500                                   exclusive_or_expression,
#    1501                                   BITWISE_OR,
#    1502                                   location):
#    1503     if len(node.children)==1:
# -> 1504         return self.visit(exclusive_or_expression)
#    1505     args = map(lambda n:self.visit(n), node.children)
#    1506     return reduceT(lambda x,y, op: {"type":"comparison", "op":op, "left":x if not isinstance(x, list) else x[0], "right":y if not isinstance(x, list) else y[0], "pseudo_type":"bool"}, list(args))
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1514, in AstTransformer.visit_exclusive_or_expression(self, node, and_expression, CARET, location)
#    1508 def visit_exclusive_or_expression(self,
#    1509                                 node,
#    1510                                 and_expression,
#    1511                                 CARET,
#    1512                                 location):
#    1513     if len(node.children)==1:
# -> 1514         return self.visit(and_expression)
#    1515     args = map(lambda n:self.visit(n), node.children)
#    1516     return reduceT(lambda x,y, op: {"type":"comparison", "op":op, "left":x if not isinstance(x, list) else x[0], "right":y if not isinstance(x, list) else y[0], "pseudo_type":"bool"}, list(args))
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1524, in AstTransformer.visit_and_expression(self, node, equality_expression, AMP, location)
#    1518 def visit_and_expression(self,
#    1519                         node,
#    1520                         equality_expression,
#    1521                         AMP,
#    1522                         location ):
#    1523     if len(node.children)==1:
# -> 1524         return self.visit(equality_expression)
#    1525     args = map(lambda n:self.visit(n), node.children)
#    1526     return reduceT(lambda x,y, op: {"type":"comparison", "op":op, "left":x if not isinstance(x, list) else x[0], "right":y if not isinstance(x, list) else y[0], "pseudo_type":"bool"}, list(args))
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1530, in AstTransformer.visit_equality_expression(self, node, relational_expression, OP_EQ, OP_NE, location)
#    1528 def visit_equality_expression(self, node, relational_expression, OP_EQ,OP_NE,location):
#    1529     if len(node.children)==1:
# -> 1530         return self.visit(relational_expression)
#    1531     args = map(lambda n:self.visit(n), node.children)
#    1532     return reduceT(lambda x,y, op: {"type":"comparison", "op":op, "left":x[0], "right":y[0], "pseudo_type":"bool"}, list(args))
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1544, in AstTransformer.visit_relational_expression(self, node, shift_expression, LT, GT, OP_LE, OP_GE, IS, isType, AS, type_, location)
#    1542     return {"type":"isExpression", "left": left, "right":right, "pseudo_type":"Void"}
#    1543 if len(node.children)==1:
# -> 1544     return self.visit(shift_expression)
#    1545 else:
#    1546     args = map(lambda n:self.visit(n), node.children)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1564, in AstTransformer.visit_shift_expression(self, node, additive_expression, OP_LEFT_SHIFT, right_shift, location)
#    1557 def visit_shift_expression(self,
#    1558                             node,
#    1559                             additive_expression,OP_LEFT_SHIFT,
#    1560                             right_shift,
#    1561                             location):
#    1563     if len(node.children)==1:
# -> 1564         return self.visit(additive_expression)[0]
#    1565     else:
#    1566         #op = OP_LEFT_SHIFT if OP_LEFT_SHIFT else right_shift
#    1567         args = map(lambda n:self.visit(n), node.children)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1572, in AstTransformer.visit_additive_expression(self, node, multiplicative_expression, PLUS, MINUS, location)
#    1570 def visit_additive_expression(self, node,multiplicative_expression, PLUS,MINUS,location):
#    1571     if len(node.children)==1:
# -> 1572         return self.visit(multiplicative_expression)
#    1573     else:
#    1574         args = map(lambda n:self.visit(n), node.children)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1581, in AstTransformer.visit_multiplicative_expression(self, node, switch_expression, STAR, DIV, PERCENT, location)
#    1579 def visit_multiplicative_expression(self, node,switch_expression, STAR,DIV,PERCENT, location):
#    1580     if len(node.children)==1:
# -> 1581         return self.visit(switch_expression)
#    1582     else:
#    1583         args = map(lambda n:self.visit(n), node.children)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1635, in AstTransformer.visit_switch_expression(self, node, range_expression, SWITCH, switch_expression_arms, location)
#    1633 def visit_switch_expression(self, node,range_expression,SWITCH,switch_expression_arms, location):
#    1634     if len(node.children)==1:
# -> 1635         return self.visit(range_expression)
#    1636     else:
#    1637         lhs = self.visit(range_expression)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1643, in AstTransformer.visit_range_expression(self, node, unary_expression, OP_RANGE, location)
#    1641 def visit_range_expression(self, node,unary_expression,OP_RANGE, location):
#    1642     if len(node.children)==1:
# -> 1643         res = self.visit(unary_expression)
#    1644         return res[0]
#    1645     else:
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:582, in AstTransformer.visit(self, node)
#     580 results = []
#     581 for n in node:
# --> 582     x = self.visit(n)
#     583     if isinstance(x, list):
#     584         results.extend(x)
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1590, in AstTransformer.visit_unary_expression(self, node, primary_expression, PLUS, type_, BANG, MINUS, OP_INC, OP_DEC, unary_expression, STAR, TILDE, location)
#    1587 def visit_unary_expression(self, node, primary_expression,PLUS,type_, BANG, MINUS,OP_INC,OP_DEC, unary_expression,STAR,TILDE, location):
#    1588     #print(location, "unarrrrrrrrrrrrrrrrrrrrrrrrry")
#    1589     if primary_expression:
# -> 1590         z =  self.visit(primary_expression)
#    1591         return z
#    1592     if type_:
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:578, in AstTransformer.visit(self, node)
#     576     else:
#     577         fields['location'] = None
# --> 578     return getattr(self, 'visit_%s' % type(node).__name__.lower())(**fields)# [:-7]
#     579 elif isinstance(node, list):
#     580     results = []
#
# File /mnt/d/Docs/PyCropML_Old/src/pycropml/transpiler/antlr_py/csharp/csharpTransformer.py:1768, in AstTransformer.visit_primary_expression(self, node, primary_expression_start, OP_INC, BANG, OP_PTR, identifier, OP_DEC, member_access, method_invocation, bracket_expression, location)
#    1766     else:
#    1767         print(res, receiver, location, "uuuuuuuuuuuu")
# -> 1768         res["member"] = receiver.split(".")[-1]
#    1769         res = {'type': 'custom_call', 'namespace': res, "function":method, 'args': args, 'pseudo_type': "unknown", "class_": self.clas[-1]}      #TODO
#    1770         #if self.assign == False:
#    1771                 #res = {"type": 'ExprStatNode', 'expr': res}
#    1772 else:
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
from pycropml.transpiler.main import Main

source = """
def toto(int x):
    cdef intlist b
    cdef int i
    b = [15,20]
    b[0]=15
    b.append(16)
    if i in b:
        x = 2
    return b
"""


cst = Main(source, 'cs')

p = cst.parse()   # convert to cst
r = cst.to_ast(source)  # convert to ast

cst.dictAst  # print ast as dict

#print(cst.to_source())   # generate code
# Out:
# {'type': 'module',
#  'definition': [<Cython.Compiler.Nodes.DefNode at 0x7f824193b590>],
#  'iterators': [],
#  'body': [{'type': 'function_definition',
#    'name': 'toto',
#    'params': [{'name': 'x', 'type': 'int', 'pseudo_type': 'int'}],
#    'pseudo_type': ['Function', 'int', ['list', 'int']],
#    'return_type': ['list', 'int'],
#    'block': [{'type': 'declaration',
#      'decl': [{'name': 'b',
#        'type': 'list',
#        'lineno': (3, 9),
#        'pseudo_type': ['list', 'int']}]},
#     {'type': 'declaration',
#      'decl': [{'name': 'i',
#        'type': 'int',
#        'lineno': (4, 9),
#        'pseudo_type': 'int'}]},
#     {'type': 'assignment',
#      'target': {'type': 'local', 'name': 'b', 'pseudo_type': ['list', 'int']},
#      'value': {'type': 'list',
#       'pseudo_type': ['list', 'int'],
#       'elements': [{'type': 'int', 'value': '15', 'pseudo_type': 'int'},
#        {'type': 'int', 'value': '20', 'pseudo_type': 'int'}]},
#      'pseudo_type': 'Void'},
#     {'type': 'assignment',
#      'target': {'type': 'index',
#       'sequence': {'type': 'local',
#        'name': 'b',
#        'pseudo_type': ['list', 'int'],
#        'lineno': (6, 4)},
#       'index': {'type': 'int', 'value': '0', 'pseudo_type': 'int'},
#       'pseudo_type': 'int'},
#      'value': {'type': 'int', 'value': '15', 'pseudo_type': 'int'},
#      'pseudo_type': 'Void'},
#     {'type': 'ExprStatNode',
#      'expr': {'type': 'standard_method_call',
#       'receiver': {'type': 'local',
#        'name': 'b',
#        'pseudo_type': ['list', 'int'],
#        'lineno': (7, 4)},
#       'message': 'append',
#       'args': [{'type': 'int', 'value': '16', 'pseudo_type': 'int'}],
#       'pseudo_type': ['list', 'int']}},
#     {'type': 'if_statement',
#      'test': {'type': 'standard_method_call',
#       'receiver': {'type': 'local',
#        'name': 'b',
#        'pseudo_type': ['list', 'int'],
#        'lineno': (8, 12)},
#       'message': 'contains?',
#       'args': [{'type': 'local',
#         'name': 'i',
#         'pseudo_type': 'int',
#         'lineno': (8, 7)}],
#       'pseudo_type': 'Boolean'},
#      'block': [{'type': 'assignment',
#        'target': {'type': 'local', 'name': 'x', 'pseudo_type': 'int'},
#        'value': {'type': 'int', 'value': '2', 'pseudo_type': 'int'},
#        'pseudo_type': 'Void'}],
#      'pseudo_type': 'Void',
#      'otherwise': []},
#     {'type': 'implicit_return',
#      'value': {'type': 'local',
#       'name': 'b',
#       'pseudo_type': ['list', 'int'],
#       'lineno': (10, 11)},
#      'pseudo_type': ['list', 'int']}],
#    'recursive': False}]}
